# %% [markdown]
# # **Introducción a Colab**

# %% [markdown]
# # Base de datos
#
#
# Una base de datos es una recopilación organizada de información o datos estructurados, que normalmente se almacena de forma electrónica en un sistema informático.

# %% [markdown]
# ### Ejemplo 1:
#
# Considerar la base de datos nations_gdp_life_pop_urban (3).csv.

# %% [markdown]
# 1. Cargar la base de datos

# %%
# Exportar la base de datos a colab
# lalalalala
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a89f76ca-3dd7-4675-ba43-d7a42e5bacf8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a89f76ca-3dd7-4675-ba43-d7a42e5bacf8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd # pandas es una librería de python que nos permite trabajar con base de datos
# Acá cargamos la librería que nos permite abrir la base de datos

# %%
# abrir en python la base de datos nations_gdp_life_pop_urban (3).csv

base=pd.read_csv('nations_gdp_life_pop_urban (3).csv',sep=';') # sep=separador

# %% [markdown]
# 2. Mostrar la información relativa a cada columna de la base de datos

# %%
# Veremos cuales son los nombres de las columnas de la base de datos
print(base.columns)
# Out:
# Index(['Unnamed: 0', 'country', 'region', 'gdp', 'life', 'pop', 'urban'], dtype='object')

# %%
base.dtypes
#Identificamos que tipo tipo de variable es cada columna
# Out:
# Unnamed: 0     int64
# country       object
# region        object
# gdp           object
# life          object
# pop            int64
# urban         object
# dtype: object

# %%
base.info()
#.info() : Nos entrega información detallada de cada variable (las entradas no nulas, tipo de variable)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  194 non-null    int64
#  1   country     194 non-null    object
#  2   region      194 non-null    object
#  3   gdp         179 non-null    object
#  4   life        194 non-null    object
#  5   pop         194 non-null    int64
#  6   urban       194 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 10.7+ KB

# %% [markdown]
# 3. Reescribir la información de las columnas 'gpd' y 'urban' como cifras decimales.

# %%
base['gdp']=base['gdp'].str.replace(',','.').astype(float)

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  194 non-null    int64
#  1   country     194 non-null    object
#  2   region      194 non-null    object
#  3   gdp         179 non-null    float64
#  4   life        194 non-null    object
#  5   pop         194 non-null    int64
#  6   urban       194 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 10.7+ KB

# %%
#Proceso inverso: De variable de punto flotante a str
base['gdp']=base['gdp'].replace('.',',').astype(str)

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  194 non-null    int64
#  1   country     194 non-null    object
#  2   region      194 non-null    object
#  3   gdp         194 non-null    object
#  4   life        194 non-null    object
#  5   pop         194 non-null    int64
#  6   urban       194 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 10.7+ KB

# %%
# Reecribir las columnas gdp y urban como cifras decimales

# %%
base['gdp'],base['urban']=base['gdp'].str.replace(',','.').astype(float),base['urban'].str.replace(',','.').astype(float)

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  194 non-null    int64
#  1   country     194 non-null    object
#  2   region      194 non-null    object
#  3   gdp         179 non-null    float64
#  4   life        194 non-null    object
#  5   pop         194 non-null    int64
#  6   urban       194 non-null    float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 10.7+ KB

# %% [markdown]
# 4. Extraer los datos correspondientes a los países europeos, cuyo porcentaje de urbanización es superior al 60%

# %%
base['region'].value_counts()
# La función value_counts determina todos los posibles valores que toma una variable
# Out:
# region
# Africa      52
# Asia        49
# Europe      43
# Americas    35
# Oceania     15
# Name: count, dtype: int64

# %%
# y = & (una variable cumple una condicion y cumple otra)
# o= | (una variable cumple una condición o cumple otra)

# %%
base1=base[(base['region']=='Europe')&(base['urban']>60)]

# %% [markdown]
# 5. Crear una nueva base de datos, que sólo contenga datos no nulos del producto interno bruto (gdp en inglés)

# %%
base.isnull().sum()
# Out:
# Unnamed: 0     0
# country        0
# region         0
# gdp           15
# life           0
# pop            0
# urban          0
# dtype: int64

# %%
base2=base.dropna()
# La función dropna nos permite eliminar todas las entradas nulas de una base de datos

# %%
# Para borrar entradas de una base de datos, que cumplan con alguna condición se utilizará la función drop

# %%
# En particular, me gustaría generar una nueva base de datos que no considere las entradas nulas ni los países de Europa

# %%
base3=base.drop(base[(base['gdp'].isnull()) | (base['region']=='Europe')].index)

# %% [markdown]
# # Ejemplo 2

# %% [markdown]
# ### Consideraremos la base de datos **bice_price.xlsx**

# %% [markdown]
# 1. Cargar la base de datos

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-35ba9f10-2197-4dfd-8e5e-ab74795acbd7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35ba9f10-2197-4dfd-8e5e-ab74795acbd7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
bike=pd.read_excel('bike_price.xlsx')

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Bike_Age          276 non-null    float64
#  1   Brand_Popularity  276 non-null    int64
#  2   Mileage           276 non-null    int64
#  3   Gear_Count        276 non-null    int64
#  4   Price             276 non-null    float64
#  5   Bike_Weight       276 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 13.1 KB

# %% [markdown]
# 2. Generar una nueva base de datos, considerando sólo las bicicletas cuyo peso es superior a 10 kg

# %%
bike2=bike[bike['Bike_Weight']>10] # Hemos creado una nueva base de datos, que contiene sólo la información relativa a las bicicletas cuyo peso
#es superior a 10

# %% [markdown]
# 3. Determinar las entradas nulas

# %%
#Tarea

# %% [markdown]
# 4. Ordenar la columna **Bike_Age** de manera descendente

# %%
bike.sort_values(by=['Bike_Age'],ascending=False)
# Ejercicio: borren las entradas basura de la base de datos
# Out:
#      Bike_Age  Brand_Popularity  Mileage  Gear_Count     Price  Bike_Weight
# 123       9.9                25     4612          24   -109.75          7.9
# 252       9.9                25     3292          18   2363.24         13.8
# 16        9.9                15     1680          27    538.47          9.4
# 167       9.8                98     2413          24  16424.99          8.5
# 109       9.7                84     4620          24  14910.34          7.6
# ..        ...               ...      ...         ...       ...          ...
# 67        0.6                70     2714          18  14319.92         13.4
# 106       0.6                60     4667          21  14149.72         10.3
# 269       0.6                67     3716          21  13908.83          9.3
# 194       0.6                51     4020          18  12924.85          9.7
# 70        0.5                59      843          21  14748.27         13.2
#
# [276 rows x 6 columns]

# %% [markdown]
# Ejercicio:
#
# A partir de la base de datos 'nations_gdp_literacy_co2_gini (1).csv', crear una nueva base de datos que sólo considera la información proveniente de Europa

# %% [markdown]
# Generar una base de datos, con los países que vienen de Europa y cuyo índice de Gini sea superior a 30

# %% [markdown]
# # Estadística Descriptiva

# %% [markdown]
# ## Medidas de tendencia central:
# Las medidas de tendencia central, o medidas de centralización, son métricas estadísticas que indican el valor central de una distribución. Es decir, las medidas de tendencia central sirven para encontrar un valor representativo del centro de un conjunto de datos. Estas son:
#
# 1. Media muestral
# 2.  Moda muestral
# 3. Mediana Muestral

# %% [markdown]
# **Definición: Media Muestral**
#
# Si las $n$ observaciones de una muestra se denotan por $x_1,x_2,\cdots,x_n$, entonces
# $$
# \bar{x}=\frac{x_1+x_2+\cdots+x_n}{n}=\frac{\sum_{i=1}^n x_i}{n}
# $$
#
# n= tamaño de la muestra
#
# **Observación:**
#
# Cuando disponemos de una tabla de datos acomulados, la media muestral se define como
# $$
# \bar{x}=\dfrac{\sum_i^n x_i f_i}{n}
# $$
#
# con,
#
# $x_i=$ marca de clase
#
# $f_i=$ frecuencia acomulada

# %% [markdown]
# **Definición: Moda Muestral**
#
# En estadística, la moda es el valor del conjunto de datos que tiene una mayor frecuencia absoluta, es decir, la moda es el valor que más se repite de un conjunto de datos.
#
# **Definición: Mediana Muestral**
#
# La mediana muestral de $n$ elementos se obtiene ordenando primero las $n$ observaciones de la más pequeña a la más grande, así
# $$
# \tilde{x}=\left\{\left(\dfrac{n+1}{2}\right),\quad n\,\mathrm{impar}\atop =\mathrm{promedio\, de\,} \left(\dfrac{n}{2}\right)\,y\,\left(\dfrac{n}{2}+1\right),\quad n\,\mathrm{par}\right.
# $$

# %% [markdown]
# Ejemplo:
#
# Considerar el conjunto
# $$
# {4,5,8,6,10,11,8,6,4,3,2,5,5}
# $$
# Determinar:

# %%
# Ingresar los datos
data=pd.DataFrame([4,5,8,6,10,11,8,6,4,3,2,5,5])

# %% [markdown]
# 1. La mediana muestral

# %%
mediana=data.median()

# %%
print(f'La mediana es {mediana}')
# Out:
# La mediana es 0    5.0
# dtype: float64

# %% [markdown]
# 2. La moda muestral

# %%
moda=data.mode()

# %%
print(f'La mediana es {moda}')
# Out:
# La mediana es    0
# 0  5

# %% [markdown]
# ### Histograma
#
# Un histograma es un diagrama en el que se representa un conjunto de datos estadísticos mediante barras rectangulares, de manera que cada barra del histograma es proporcional a su frecuencia correspondiente.
#
# Los histogramas sirven para representar gráficamente variables continua.

# %% [markdown]
# Ejemplo:
#
# https://media.gcflearnfree.org/content/61d5c21ec4da77185ca9f22a_01_05_2022/Ejemplo-de-histograma-de-datos.png

# %% [markdown]
# ### Gráfica de barras
#
# Una gráfica de barras, es una manera  de representar datos, mediante barras verticales u horizontales y se utilizan para mostrar comparaciones entre diferentes magnitudes.
#
# La longitud de cada barra es proporcional al valor que representa

# %% [markdown]
# Ejemplo:
#
# https://cdn.quehowto.com/wp-content/uploads/2019/07/grafico-de-barras-1200-amp.jpg

# %% [markdown]
# **Ejemplo**
#
# La base de datos ‘tips‘ es un conjunto de datos que contiene información relacionada con propinas recolectadas
# en un restaurante. El objetivo de su análisis es identificar y describir las características clave de las variables
# que influyen en las propinas, así como las relaciones entre estas variables. Los datos contienen información sobre
# las cuentas totales, propinas, características de los clientes (como su sexo y si son fumadores o no), además del
# contexto temporal (día de la semana y momento del día en que se realizó la observación).
#
#
# Para desarrollar esta actividad necesita cargar la base de datos desde la libreria seaborn siguiendo los siguientes
# pasos:
#
# Paso 1: Importar la librería seaborn utilizando import seaborn as sns.
#
# Paso 2: Cargar la base de datos de la librería utilizando sns.load_dataset('tips').
# Utilizando las librerías y funciones adecuada, responda las siguientes preguntas.

# %%
import seaborn as sns

# %%
tip=sns.load_dataset('tips')

# %% [markdown]
# 1. Determinar la propina media, que suele dejar el grupo de los fumadores

# %%
# total_bill= cuenta total
# tip= propina
# sex= sexo
#smoker= fumador o no
#time= el momento del día donde se realizó la observación
# day= día de la semana donde se realizó la observación
#size= tamaño de la mesa

# %% [markdown]
# $$
# \bar{x}=\frac{x_1+x_2+\cdots+x_n}{n}=\frac{\sum_{i=1}^n x_i}{n}
# $$

# %%
# Seleccionamos a los fumadores
fumadores=tip[tip['smoker']=='Yes']

# %%
# Determinamos la propina de los smoker
propina_media=fumadores['tip'].mean()

# %%
print(f'La propina media es: {round(propina_media,2)}')
# La función round aproxima a las cifras decimales que estimemos conveniente
# Out:
# La propina media es: 3.01

# %% [markdown]
# 2. Realice un histograma que permita visualizar la curva de densidad y la media de la variable 'tip' bajo estás condiciones. Además, importar a su computador esta imagen

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#librerias que nos permiten trabajar con gráficas estadísticas

# %%
fig=plt.figure(figsize=(6,5))
sns.histplot(fumadores['tip'],color='black',kde=True) #sns.histplot(datos,color,bins=subintervalos,kde=Linea de tendencia central)
plt.axvline(propina_media,color='red',linestyle=':',label=f'media = {propina_media}') #propina media: línea vertical
plt.legend() # PAra visualizar las etiquetas de la gráfica
plt.title('Histograma de las propinas')
###### PROCEDER A EXPORTAR IMAGEN
from google.colab import files
plt.savefig('Histograma.pdf') # Guardamos el histograma
files.download('Histograma.pdf') # Descargamos la imagen
plt.show()

# %% [markdown]
# 3. Determinar el total facturado medio, correspondiente a las mesas que son ocupadas por 3 individuos o más y que asisten a cenar.

# %% [markdown]
# # Tarea

# %% [markdown]
# 4. Realizar una gráfica de barras para el momento del día donde se realizó la transacción y el total promedio facturado

# %% [markdown]
# **Gráfica de barras**
#
# Una gráfica de barras, es una manera  de representar datos, mediante barras verticales u horizontales. La longitud de estas es proporcional a la magnitud que representan.

# %%
# Gráfica de barras
# x= total bill (variable númerica)
# y = time (momento del día donde se realizó la transacción) variable categórica

# %%
fig=plt.figure(figsize=(8,6))
sns.barplot(x='total_bill',y='time',hue='smoker',data=tip,errorbar=None,estimator='mean') #sns.barplot (x='variable numerica',y='variable categorica',data= base de datos)
plt.show()
#hue=nos permite agrupar por subgrupos la variable categórica

# %% [markdown]
# **Definición: Cuartiles**
#
# En estadística, los cuartiles son los tres valores que dividen a un conjunto de datos ordenados en cuatro partes iguales. Por lo tanto, el primer, segundo y tercer cuartil representan respectivamente el 25%, 50% y 75% del conjunto de datos estadísticos.
#
# Los cuartiles se representan mediante una $Q$ mayúscula y el subíndice del cuartil, de manera que el primer cuartil es $Q_1$, el segundo cuartil es $Q_2$, y el tercer cuartil es $Q_3$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ejemplo:
#
# De la base de datos tips, definiremos el primer, segundo y tercer cuartil de la variable total bill

# %%
# Cargar librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base=sns.load_dataset('tips')

# %%
base.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
primer_cuartil=base['total_bill'].quantile(0.25)

# %%
print(f' Q_1 : {round(primer_cuartil,2)}')
# Out:
#  Q_1 : 13.35

# %%
segundo_cuartil=base['total_bill'].quantile(0.5)

# %%
print(f' Q_2: {segundo_cuartil}')
# Out:
#  Q_2: 17.795

# %% [markdown]
# Ejemplo:
#
# Determinar las principales medidas estadísticas de la variable 'total_bill'

# %%
round(base['total_bill'].describe(),5)
# Out:
# count    244.00000
# mean      19.78594
# std        8.90241
# min        3.07000
# 25%       13.34750
# 50%       17.79500
# 75%       24.12750
# max       50.81000
# Name: total_bill, dtype: float64

# %%
# La función .describe() nos permite conocer las principales medidas estadísticas de un conjunto de datos:
# count= numero de observaciones
# mean= media
# std=?
# min= el valor mínimo del conjunto de datos
# 25% = Primer cuartil
# 50% = Segundo cuartil
# 75%= Tercer cuartil
# máx= valor máximo del conjunto

# %% [markdown]
# **Ejemplo**
#
# La base de datos ‘titanic‘ es una muestra de los pasajeros del titanic. Contiene información de  891 pasajeros, su edad, el número de familiares de cada uno, la clase en la que viajaban y el precio del billete que habían pagado. También se sabe si son sobrevivientes o no.

# %% [markdown]
# Determinar y comente las principales medidas descriptivas de la edad de las mujeres que no sobrevivieron al naufragio. Además realice un histograma que permita visualizar la curva de densidad y la media de la variable 'age' bajo estás condiciones.

# %% [markdown]
# ### Gráfica de caja y bigotes:
#
# Una gráfica de cajas  es una representación de un conjunto de datos númericos, utilizando los cuartiles.
#
# La principal característica del diagrama de caja y bigotes es que permite visualizar rápidamente la dispersión de una serie de datos, ya que indica los cuartiles, la mediana, los valores extremos y los valores atípicos de los datos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ejemplo:
#
# Realizar una gráfica de caja y bigotes de las edades de las mujeres que viajaron en el titanic.

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# Seleccionar de las mujeres que viajaban en el barco
mujeres=titanic[titanic['sex']=='female'].dropna()

# %%
# Gráfica de caja y bigotes
fig=plt.figure(figsize=(6,4))
sns.boxplot(x=mujeres['age'],y=mujeres['sex'],color='black')
plt.axvline(mujeres['age'].median(),color='red',label=f'Mediana')
plt.legend()
plt.show()

# %%
# Gráfica de caja y bigotes
fig=plt.figure(figsize=(6,4))
sns.boxplot(x=titanic['age'],y=titanic['sex'],color='pink')
#plt.axvline(mujeres['age'].median(),color='red',label=f'Mediana')
#plt.legend()
plt.show()
