# %%
#shape 
#indica la forma que tiene un arreglo 
#la forma de un arreglo entrega la estrctura de un arreglo, que tan coroto es un arreglo y como se puede ingresar a el y como arreglarlo 
import numpy as np

# %%
arr = np.array([13, 6, 3, 5, 10])
np.max(arr)
# Out:
# 13

# %%
arr=np.random.randint(1,10, (3,2))
arr
# Out:
# array([[4, 2],
#        [2, 6],
#        [6, 9]])

# %%
#cuantas filas y columnas se tiene 
arr.shape
# Out:
# (3, 2)

# %%
#cambiar la forma establecida de mi array
arr.reshape(1,6)
# Out:
# array([[4, 2, 2, 6, 6, 9]])

# %%
np.reshape(arr, (1,6))
# Out:
# array([[4, 2, 2, 6, 6, 9]])

# %%
arr
# Out:
# array([[4, 2],
#        [2, 6],
#        [6, 9]])

# %%
#Se puede hacer un reshape como lo haría C.
np.reshape(arr, (2,3), "C")
# Out:
# array([[4, 2, 2],
#        [6, 6, 9]])

# %%
#También se puede hacer reshape a como lo haría Fortran.
np.reshape(arr, (2,3), "F")
# Out:
# array([[4, 6, 6],
#        [2, 2, 9]])

# %%
#Además existe la opción de hacer reshape según como esté optimizado nuestro computador. En este caso es como en C.
np.reshape(arr, (2,3), "A")
# Out:
# array([[4, 2, 2],
#        [6, 6, 9]])

# %%
#no se puede cmabiar la forma, debe tener una forma de 6 elementos y la forma debe mantener esos elementos
