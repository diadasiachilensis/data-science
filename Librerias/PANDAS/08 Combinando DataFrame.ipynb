# %%
import pandas as pd
import numpy as np

# %%
arr = np.array([13, 6, 3, 5, 10])
np.sort(arr)
# Out:
# array([ 3,  5,  6, 10, 13])

# %% [markdown]
# ##Merge - Join
#
# *   **Left join:** da prioridad al dataFrame de la izquierda. Trae siempre los datos de la izquierda y las filas en comun con el dataFrame de la derecha.
# *   **Right join:** da prioridad al dataFrame de la derecha. Trae siempre los datos de la derecha y las filas en comun con el dataFrame de la izquierda.
# *   **Inner join:** Trae solamente aquellos datos que son común en ambos dataFrame
# *   **Outer join:** Trae los datos tanto del dataFrame de la izquierda como el de la derecha incluyendo los datos que comparten ambos.
#
# *   **Concat - Axis 0:** permite combinar dos dataframes a nivel de filas. Crecimiento vertical.
# *   **Concat - Axis 1:** permite combinar dos dataframes a nivel de columnas. La organizacion por columnas no va a ser la misma para ambos dataFrames, por tanto, se crearan valores NaN para rellenar los espacios vacios. Crecimiento horizontal

# %%
df1=pd.DataFrame(
{ 'A':['A0','A1','A2','A3',],
  'B':['B0','B1','B2','B3',],
  'C':['C0','C1','C2','C3',],
  'D':['D0','D1','D2','D3',],
 })

df2=pd.DataFrame(
{ 'A':['A4','A5','A6','A7',],
  'B':['B4','B5','B6','B7',],
  'C':['C4','C5','C6','C7',],
  'D':['D4','D5','D6','D7',],
 })

# %% [markdown]
# #Concat

# %%
#se concatenan todos los valores 
#los indices heredan los indices anterior
pd.concat([df1,df2])
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
pd.concat([df1,df2],ignore_index=True)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pd.concat([df1,df2], ignore_index=True)
#respsta los indices y los reordena
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pd.concat([df1,df2], axis=1)
#amplia de menra horizontal (columnar)
# Out:
#     A   B   C   D   A   B   C   D
# 0  A0  B0  C0  D0  A4  B4  C4  D4
# 1  A1  B1  C1  D1  A5  B5  C5  D5
# 2  A2  B2  C2  D2  A6  B6  C6  D6
# 3  A3  B3  C3  D3  A7  B7  C7  D7

# %% [markdown]
# #Merge

# %%
 izq = pd.DataFrame({
'key' : ['k0', 'k1', 'k2','k3'],
'A' : ['A0', 'A1', 'A2','A3'],
'B': ['B0', 'B1', 'B2','B3']
})

der = pd.DataFrame({
'key' : ['k0', 'k1', 'k2','k3'],
'C' : ['C0', 'C1', 'C2','C3'],
'D': ['D0', 'D1', 'D2','D3']
})

# %%
izq.merge(der, on='key')
#asi se puede hacer join de varios lados
# Out:
#   key   A   B   C   D
# 0  k0  A0  B0  C0  D0
# 1  k1  A1  B1  C1  D1
# 2  k2  A2  B2  C2  D2
# 3  k3  A3  B3  C3  D3

# %%
izq.merge(der)
# Out:
#   key   A   B   C   D
# 0  k0  A0  B0  C0  D0
# 1  k1  A1  B1  C1  D1
# 2  k2  A2  B2  C2  D2
# 3  k3  A3  B3  C3  D3

# %%
izq = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'A' : ['A0', 'A1', 'A2','A3'],
'B': ['B0', 'B1', 'B2','B3']})

der = pd.DataFrame({'key_2' : ['k0', 'k1', 'k2','k3'],
 'C' : ['C0', 'C1', 'C2','C3'],
'D': ['D0', 'D1', 'D2','D3']})

# %%
izq.merge(der, on='key')
#falla porque 'key' esta en un solo dattaframe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-316672b5e161> in <module>()
# ----> 1 izq.merge(der, on='key')
#       2 #falla porque 'key' esta en un solo dattaframe
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9201             copy=copy,
#    9202             indicator=indicator,
# -> 9203             validate=validate,
#    9204         )
#    9205
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# ...

# %%
#a partir de lo anterior lo que sirve hacder es
izq.merge(der, left_on='key',right_on='key_2')
# Out:
#   key   A   B key_2   C   D
# 0  k0  A0  B0    k0  C0  D0
# 1  k1  A1  B1    k1  C1  D1
# 2  k2  A2  B2    k2  C2  D2
# 3  k3  A3  B3    k3  C3  D3

# %%
izq = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'A' : ['A0', 'A1', 'A2','A3'],
'B': ['B0', 'B1', 'B2','B3']})

der = pd.DataFrame({'key_2' : ['k0', 'k1', 'k2',np.nan],
 'C' : ['C0', 'C1', 'C2','C3'],
'D': ['D0', 'D1', 'D2','D3']})

# %%
der
#que opasa si una de las filas no tiene un valor no tiene un tipode dato
# Out:
#   key_2   C   D
# 0    k0  C0  D0
# 1    k1  C1  D1
# 2    k2  C2  D2
# 3   NaN  C3  D3

# %%
izq.merge(der, left_on='key',right_on='key_2')
#no hace match por lo tanto no desarrolla el index 3 
#solo hace las coincidencias, la interseccion
# Out:
#   key   A   B key_2   C   D
# 0  k0  A0  B0    k0  C0  D0
# 1  k1  A1  B1    k1  C1  D1
# 2  k2  A2  B2    k2  C2  D2

# %%
#para un left join
izq.merge(der, left_on='key',right_on='key_2', how='left')
# Out:
#   key   A   B key_2    C    D
# 0  k0  A0  B0    k0   C0   D0
# 1  k1  A1  B1    k1   C1   D1
# 2  k2  A2  B2    k2   C2   D2
# 3  k3  A3  B3   NaN  NaN  NaN

# %%
izq.merge(der, left_on='key',right_on='key_2', how='inner')
#"how='inner'":para es un valor por default
# Out:
#   key   A   B key_2   C   D
# 0  k0  A0  B0    k0  C0  D0
# 1  k1  A1  B1    k1  C1  D1
# 2  k2  A2  B2    k2  C2  D2

# %%
#para un right join
izq.merge(der, left_on='key',right_on='key_2', how='right')
# Out:
#    key    A    B key_2   C   D
# 0   k0   A0   B0    k0  C0  D0
# 1   k1   A1   B1    k1  C1  D1
# 2   k2   A2   B2    k2  C2  D2
# 3  NaN  NaN  NaN   NaN  C3  D3

# %% [markdown]
# #Join

# %%
izq = pd.DataFrame({'A': ['A0','A1','A2'],
  'B':['B0','B1','B2']},
  index=['k0','k1','k2'])

der =pd.DataFrame({'C': ['C0','C1','C2'],
  'D':['D0','D1','D2']},
  index=['k0','k2','k3'])

# %%
izq.join(der)
#lo hace directamnet de los indices ko, k1 y k2
# Out:
#      A   B    C    D
# k0  A0  B0   C0   D0
# k1  A1  B1  NaN  NaN
# k2  A2  B2   C1   D1

# %%
izq.join(der, how='inner')
#solo aparece el k0 y k2 porque es el unico que hace match entre los dos diccionarios
# Out:
#      A   B   C   D
# k0  A0  B0  C0  D0
# k2  A2  B2  C1  D1

# %%
izq.join(der, how='left')
# Out:
#      A   B    C    D
# k0  A0  B0   C0   D0
# k1  A1  B1  NaN  NaN
# k2  A2  B2   C1   D1

# %%
izq.join(der, how='right')
# Out:
#       A    B   C   D
# k0   A0   B0  C0  D0
# k2   A2   B2  C1  D1
# k3  NaN  NaN  C2  D2

# %%
#"how='outer'" respeta los join pero sin importar si los datos estan inscritos
izq.join(der, how='outer')
# Out:
#       A    B    C    D
# k0   A0   B0   C0   D0
# k1   A1   B1  NaN  NaN
# k2   A2   B2   C1   D1
# k3  NaN  NaN   C2   D2
