# %%
import pandas as pd

# %%
psg_players=pd.Series(['Navas','Mbappe','Neymar','Messi'],
          index=[1,7,10,30]
          )
psg_players
# Out:
# 1      Navas
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
dict={1:'Naves',7:'Mbappe',10:'Neymar', 30:'Messi'}
pd.Series(dict)
# Out:
# 1      Naves
# 7     Mbappe
# 10    Neymar
# 30     Messi
# dtype: object

# %%
#da error porque no tiene posición cero, yoo entro por el indice, no por la posición a una dato
psg_players(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4c120274584b> in <module>()
#       1 #da error porque no tiene posición cero, yoo entro por el indice, no por la posición a una dato
# ----> 2 psg_players(0)
#
# TypeError: 'Series' object is not callable

# %%
dict={'Jugador':['Luis Suárez','Jorge Molina', 'Antonio Puertas', 'Germán Sánchez', 'Luis Milla', 'Luís Manuel Arantes Maximiano'],
  'Posición':['Delantero', 'Delantero', 'Centrocampista', 'Defensa', 'Centrocampista', 'Portero'],
  'Número':[9, 23, 10, 6, 5, 1],
  'Altura':[185.0, 187.0, 185.0, 187.0, 175.0, 190.0],
  'Goles':[7, 7, 5, 2, 2, 0] }

# %%
 #estructura matricial indexiada por columnas y filas
df_Players=pd.DataFrame(dict,index=[1,7,10,30,18,9])
df_Players
# Out:
#                           Jugador        Posición  Número  Altura  Goles
# 1                     Luis Suárez       Delantero       9   185.0      7
# 7                    Jorge Molina       Delantero      23   187.0      7
# 10                Antonio Puertas  Centrocampista      10   185.0      5
# 30                 Germán Sánchez         Defensa       6   187.0      2
# 18                     Luis Milla  Centrocampista       5   175.0      2
# 9   Luís Manuel Arantes Maximiano         Portero       1   190.0      0

# %%
df_Players.columns
df_Players.index
# Out:
# Int64Index([1, 7, 10, 30, 18, 9], dtype='int64')

# %%
#para llevar a una estrctura de datos de pandas se debe hacer
#estrctura matricial con indice de columnas y filas 
pd.DataFrame(dict)
# Out:
#                          Jugador        Posición  Número  Altura  Goles
# 0                    Luis Suárez       Delantero       9   185.0      7
# 1                   Jorge Molina       Delantero      23   187.0      7
# 2                Antonio Puertas  Centrocampista      10   185.0      5
# 3                 Germán Sánchez         Defensa       6   187.0      2
# 4                     Luis Milla  Centrocampista       5   175.0      2
# 5  Luís Manuel Arantes Maximiano         Portero       1   190.0      0
