# %%
import pandas as pd

# %%
#header=: sirve para encabezar como titulo de las columnas la fila que se escoge del codumento 
#sep=: sirve para separar 
#names=: sirve para colocar nombres a las columnas, fijate en la columna 'Name_cambiado'

df_books=pd.read_csv('/content/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv',sep=',',header=0, names=['Name_cambiado','Author','User Rating','Reviews','Price','Year','Genre'])
df_books
# Out:
#                                          Name_cambiado  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
pd.read_json('/content/hpcharactersdataraw.json', typ='Series')
# Out:
# 0       {'Name': 'Mrs. Abbott', 'Link': 'https://www.h...
# 1       {'Name': 'Hannah Abbott', 'Link': 'https://www...
# 2       {'Name': 'Abel Treetops', 'Link': 'https://www...
# 3       {'Name': 'Euan Abercrombie', 'Link': 'https://...
# 4       {'Name': 'Aberforth Dumbledore', 'Link': 'http...
#                               ...
# 1935    {'Name': 'Georgi Zdravko', 'Link': 'https://ww...
# 1936    {'Name': 'Zograf', 'Link': 'https://www.hp-lex...
# 1937    {'Name': 'Zonko', 'Link': 'https://www.hp-lexi...
# 1938    {'Name': 'Valentina Vázquez', 'Link': 'https:/...
# 1939    {'Name': 'Zygmunt Budge', 'Link': 'https://www...
# Length: 1940, dtype: object

# %% [markdown]
# #Iloc y loc
#
# *   Loc es a traves de labels
# *   Iloc es a traves de indexs

# %% [markdown]
# ##Filtrar datos sin Loc e Iloc

# %%
#filtrar en filas
df_books[0:4]
# Out:
#                              Name_cambiado              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
# 3                   1984 (Signet Classics)       George Orwell          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction
# 3    21424      6  2017      Fiction

# %%
#filtrar en columnas
df_books['Author']
# Out:
# 0                      JJ Smith
# 1                  Stephen King
# 2            Jordan B. Peterson
# 3                 George Orwell
# 4      National Geographic Kids
#                  ...
# 545                 Jeff Kinney
# 546                 Jen Sincero
# 547                 Jen Sincero
# 548                 Jen Sincero
# 549                 Jen Sincero
# Name: Author, Length: 550, dtype: object

# %%
#dos columnas
df_books[['Name_cambiado','Author']]
# Out:
#                                          Name_cambiado  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# ..                        ...
# 545               Jeff Kinney
# 546               Jen Sincero
# ...

# %% [markdown]
# ##Loc

# %%
df_books.loc[:]
# Out:
#                                          Name_cambiado  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#incluye la ultima posición
df_books.loc[0:4]
# Out:
#                                        Name_cambiado  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df_books.loc[0:4, ['Name_cambiado', 'Author']]
# Out:
#                                        Name_cambiado                    Author
# 0                      10-Day Green Smoothie Cleanse                  JJ Smith
# 1                                  11/22/63: A Novel              Stephen King
# 2            12 Rules for Life: An Antidote to Chaos        Jordan B. Peterson
# 3                             1984 (Signet Classics)             George Orwell
# 4  5,000 Awesome Facts (About Everything!) (Natio...  National Geographic Kids

# %%
#te señala quien cumple con el dato perteneciente a la columna que se señala entre []
df_books.loc[0:4, ['Author']]== 'Stephen King'
# Out:
#    Author
# 0   False
# 1    True
# 2   False
# 3   False
# 4   False

# %% [markdown]
# ##Iloc

# %%
df_books.iloc[:]
# Out:
#                                          Name_cambiado  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
#la busqueda la hace por indice 
#le dice quiero todas las filas, pero las columnas de la cero a la tres
#lo anterior se resume así df_books.iloc[filas, columnas]
df_books.iloc[:,0:3]
# Out:
#                                          Name_cambiado  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating
# 0                    JJ Smith          4.7
# 1                Stephen King          4.6
# 2          Jordan B. Peterson          4.7
# 3               George Orwell          4.7
# 4    National Geographic Kids          4.8
# ...

# %%
df_books.iloc[1,3]
# Out:
# 2052

# %%
df_books.iloc[:2,2:]
# Out:
#    User Rating  Reviews  Price  Year        Genre
# 0          4.7    17350      8  2016  Non Fiction
# 1          4.6     2052     22  2011      Fiction
